# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=["EIN", "NAME"])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df.value_counts("APPLICATION_TYPE")
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ["T9", "T13", "T12", "T2", "T14", "T25", "T29", "T15", "T17"]

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df.value_counts("CLASSIFICATION")
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C2190        1
# C2380        1
# C2500        1
# C2561        1
# C8210        1
# Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts = application_df.value_counts("CLASSIFICATION")
classification_counts[classification_counts > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1235        9
# C1237        9
# C7210        7
# C1720        6
# C4100        6
# C2400        6
# C1600        5
# C1257        5
# C2710        3
# C1260        3
# C0           3
# C1267        2
# C1246        2
# C1256        2
# C3200        2
# C1234        2
# dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = []
for j in range(len(classification_counts)):
  if classification_counts[j] < 1883:
    classifications_to_replace.append(classification_counts.index[j])

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df_num = pd.get_dummies(application_df)

# %%
application_df_num.nunique()
# Out:
# STATUS                             2
# ASK_AMT                         8747
# IS_SUCCESSFUL                      2
# APPLICATION_TYPE_Other             2
# APPLICATION_TYPE_T10               2
# APPLICATION_TYPE_T19               2
# APPLICATION_TYPE_T3                2
# APPLICATION_TYPE_T4                2
# APPLICATION_TYPE_T5                2
# APPLICATION_TYPE_T6                2
# APPLICATION_TYPE_T7                2
# APPLICATION_TYPE_T8                2
# AFFILIATION_CompanySponsored       2
# AFFILIATION_Family/Parent          2
# AFFILIATION_Independent            2
# AFFILIATION_National               2
# AFFILIATION_Other                  2
# AFFILIATION_Regional               2
# CLASSIFICATION_C1000               2
# CLASSIFICATION_C1200               2
# CLASSIFICATION_C2000               2
# CLASSIFICATION_C2100               2
# CLASSIFICATION_C3000               2
# CLASSIFICATION_Other               2
# USE_CASE_CommunityServ             2
# USE_CASE_Heathcare                 2
# USE_CASE_Other                     2
# USE_CASE_Preservation              2
# USE_CASE_ProductDev                2
# ORGANIZATION_Association           2
# ORGANIZATION_Co-operative          2
# ORGANIZATION_Corporation           2
# ORGANIZATION_Trust                 2
# INCOME_AMT_0                       2
# INCOME_AMT_1-9999                  2
# INCOME_AMT_10000-24999             2
# INCOME_AMT_100000-499999           2
# INCOME_AMT_10M-50M                 2
# INCOME_AMT_1M-5M                   2
# INCOME_AMT_25000-99999             2
# INCOME_AMT_50M+                    2
# INCOME_AMT_5M-10M                  2
# SPECIAL_CONSIDERATIONS_N           2
# SPECIAL_CONSIDERATIONS_Y           2
# dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
y = application_df_num["IS_SUCCESSFUL"].values
X = application_df_num.drop(columns="IS_SUCCESSFUL").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
print(len(X_train[0]))
print(len(X_test[0]))
# Out:
# 43
# 43

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
# Number of input features * 3
hidden_nodes_layer1 = 129
# Number of input features * 2
hidden_nodes_layer2 = 86

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="tanh"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 129)               5676
#
#  dense_1 (Dense)             (None, 86)                11180
#
#  dense_2 (Dense)             (None, 1)                 87
#
# =================================================================
# Total params: 16943 (66.18 KB)
# Trainable params: 16943 (66.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 14s 3ms/step - loss: 0.7577 - accuracy: 0.6908
# Epoch 2/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6615 - accuracy: 0.7250
# Epoch 3/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.6489 - accuracy: 0.7211
# Epoch 4/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.6249 - accuracy: 0.7248
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6015 - accuracy: 0.7236
# Epoch 6/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6286 - accuracy: 0.7090
# Epoch 7/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6142 - accuracy: 0.7226
# Epoch 8/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5893 - accuracy: 0.7262
# Epoch 9/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5771 - accuracy: 0.7296
# Epoch 10/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5830 - accuracy: 0.7313
# Epoch 11/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5865 - accuracy: 0.7232
# Epoch 12/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5812 - accuracy: 0.7303
# Epoch 13/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5732 - accuracy: 0.7318
# Epoch 14/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5738 - accuracy: 0.7302
# Epoch 15/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5706 - accuracy: 0.7308
# Epoch 16/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5706 - accuracy: 0.7334
# Epoch 17/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5680 - accuracy: 0.7338
# Epoch 18/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5660 - accuracy: 0.7320
# Epoch 19/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5680 - accuracy: 0.7340
# Epoch 20/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5630 - accuracy: 0.7353
# Epoch 21/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5595 - accuracy: 0.7359
# Epoch 22/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5584 - accuracy: 0.7327
# Epoch 23/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5586 - accuracy: 0.7334
# Epoch 24/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5532 - accuracy: 0.7358
# Epoch 25/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5537 - accuracy: 0.7350
# Epoch 26/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5598 - accuracy: 0.7344
# Epoch 27/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5560 - accuracy: 0.7354
# Epoch 28/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5592 - accuracy: 0.7352
# Epoch 29/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5609 - accuracy: 0.7360
# Epoch 30/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5583 - accuracy: 0.7358
# Epoch 31/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5551 - accuracy: 0.7348
# Epoch 32/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5662 - accuracy: 0.7348
# Epoch 33/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5710 - accuracy: 0.7363
# Epoch 34/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5575 - accuracy: 0.7358
# Epoch 35/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5555 - accuracy: 0.7370
# Epoch 36/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5552 - accuracy: 0.7364
# Epoch 37/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5520 - accuracy: 0.7378
# Epoch 38/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5510 - accuracy: 0.7371
# Epoch 39/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5568 - accuracy: 0.7368
# Epoch 40/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5610 - accuracy: 0.7372
# Epoch 41/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5579 - accuracy: 0.7361
# Epoch 42/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5555 - accuracy: 0.7364
# Epoch 43/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5536 - accuracy: 0.7374
# Epoch 44/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5558 - accuracy: 0.7372
# Epoch 45/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5503 - accuracy: 0.7386
# Epoch 46/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5489 - accuracy: 0.7378
# Epoch 47/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5490 - accuracy: 0.7383
# Epoch 48/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5515 - accuracy: 0.7377
# Epoch 49/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5493 - accuracy: 0.7384
# Epoch 50/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5484 - accuracy: 0.7394
# Epoch 51/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5503 - accuracy: 0.7367
# Epoch 52/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5487 - accuracy: 0.7382
# Epoch 53/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5520 - accuracy: 0.7377
# Epoch 54/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5531 - accuracy: 0.7390
# Epoch 55/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5521 - accuracy: 0.7381
# Epoch 56/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5592 - accuracy: 0.7357
# Epoch 57/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5586 - accuracy: 0.7392
# Epoch 58/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5513 - accuracy: 0.7388
# Epoch 59/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5589 - accuracy: 0.7383
# Epoch 60/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5557 - accuracy: 0.7377
# Epoch 61/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5541 - accuracy: 0.7379
# Epoch 62/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5542 - accuracy: 0.7382
# Epoch 63/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5586 - accuracy: 0.7386
# Epoch 64/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5541 - accuracy: 0.7389
# Epoch 65/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5540 - accuracy: 0.7380
# Epoch 66/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5553 - accuracy: 0.7381
# Epoch 67/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5538 - accuracy: 0.7372
# Epoch 68/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5568 - accuracy: 0.7379
# Epoch 69/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5523 - accuracy: 0.7397
# Epoch 70/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5495 - accuracy: 0.7396
# Epoch 71/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5510 - accuracy: 0.7394
# Epoch 72/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5549 - accuracy: 0.7387
# Epoch 73/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5569 - accuracy: 0.7385
# Epoch 74/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5574 - accuracy: 0.7387
# Epoch 75/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5561 - accuracy: 0.7380
# Epoch 76/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5531 - accuracy: 0.7383
# Epoch 77/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5547 - accuracy: 0.7394
# Epoch 78/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5521 - accuracy: 0.7393
# Epoch 79/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5501 - accuracy: 0.7392
# Epoch 80/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5512 - accuracy: 0.7388
# Epoch 81/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5487 - accuracy: 0.7389
# Epoch 82/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5483 - accuracy: 0.7397
# Epoch 83/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5465 - accuracy: 0.7390
# Epoch 84/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5462 - accuracy: 0.7395
# Epoch 85/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5484 - accuracy: 0.7394
# Epoch 86/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5479 - accuracy: 0.7399
# Epoch 87/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5471 - accuracy: 0.7388
# Epoch 88/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5419 - accuracy: 0.7391
# Epoch 89/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5410 - accuracy: 0.7397
# Epoch 90/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5485 - accuracy: 0.7390
# Epoch 91/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5490 - accuracy: 0.7389
# Epoch 92/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5532 - accuracy: 0.7397
# Epoch 93/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5484 - accuracy: 0.7400
# Epoch 94/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5490 - accuracy: 0.7395
# Epoch 95/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5502 - accuracy: 0.7395
# Epoch 96/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5515 - accuracy: 0.7393
# Epoch 97/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5439 - accuracy: 0.7397
# Epoch 98/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5462 - accuracy: 0.7407
# Epoch 99/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5459 - accuracy: 0.7397
# Epoch 100/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5493 - accuracy: 0.7398

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5821 - accuracy: 0.7235 - 618ms/epoch - 2ms/step
# Loss: 0.5820773839950562, Accuracy: 0.723498523235321

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
